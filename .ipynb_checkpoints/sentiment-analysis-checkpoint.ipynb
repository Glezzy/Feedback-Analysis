# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
# train model using the amazon data. 

amazon = pd.read_csv('data/amazon.txt', delimiter='\t', header=None)
amazon.columns = ['message', 'positive']

#standardize to lowercase
amazon.message = amazon.message.apply(lambda x: str(x).lower())

# %%
amazon[amazon['positive'] == 1].head()
# Out:
#                                         message  positive
# 1                   good case, excellent value.         1
# 2                        great for the jawbone.         1
# 4                             the mic is great.         1
# 7   if you are razr owner...you must have this!         1
# 10              and the sound quality is great.         1

# %%
keywords = ['great', 'good', 'excellent', 'love', 'like','liked','quality'
           ,'awesome', 'enjoy', 'impressed', 'satisfied', 'well', 'recommend',
           'sweet', 'sweetest', 'secure', 'best', 'easy', 'winner', 'comfortable',
           'impressive', 'inexpensive', 'beautiful', 'pretty', 'nice', 'funny',
           'value', 'ideal', 'happy']

# %%
for key in keywords:
    amazon[str(key)] = amazon.message.str.contains(str(key), case=False)

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(amazon.corr())
plt.show()

# %%
# We don't have a lot of correlation so that is perfect. Many times in positive reviews
# there will be multiple positive words in the same sentence.

# %%
data = amazon[keywords]
target = amazon['positive']

# data is boolean so we are going to use BernoulliNB
from sklearn.naive_bayes import BernoulliNB
# rename to shorter
bern = BernoulliNB()

# fit model to data
bern.fit(data, target)

# classify prediction and store as new variable
amazon['predicted'] = bern.predict(data)

# display results and accuracy
print('Number of mislabeled  points out of a total {} points: {}'.format(len(data),
                                                                        (target != amazon.predicted).sum()))
print('Model accuracy (training data): ', accuracy_score(amazon.positive,
                                                        amazon.predicted))
# Out:
# Number of mislabeled  points out of a total 1000 points: 238
# Model accuracy (training data):  0.762

# %%
# look at misclassified statements to add more keywords
amazon[amazon['positive'] != amazon['predicted']].message.head()

# iterate and increase keywords
# Out:
# 7           if you are razr owner...you must have this!
# 11    he was very impressed when going from the orig...
# 23    i have yet to run this new battery below two b...
# 45                       it has all the features i want
# 52    a usable keyboard actually turns a pda into a ...
# Name: message, dtype: object

# %%
# test on yelp data
# import data 
yelp = pd.read_csv('data/yelp.txt', delimiter = '\t', header=None)
yelp.columns = ['message', 'positive']

# standardize case
yelp['message'] = yelp['message'].apply(lambda x: str(x).lower())

# write loop to check for keywords in yelp messages, populate data input
for key in keywords:
    yelp[str(key)] = yelp.message.str.contains(str(key), case=False)
    
# specify training input from
yelp_data = yelp[keywords]
yelp_target = yelp['positive']

# predict and store as new variable
yelp['prediction'] = bern.predict(yelp_data)

# display results and accuracy
print('Number of mislabeled point out of a total {} points: {}'.format(len(yelp_target),
                                                                      (yelp_target != yelp.prediction).sum()))
print('Model accuracyon yelp data: ', accuracy_score(yelp.positive, yelp.prediction))
# Out:
# Number of mislabeled point out of a total 1000 points: 318
# Model accuracyon yelp data:  0.682

# %%
# test on imdb data

# import data
imdb = pd.read_csv('data/imdb.txt', delimiter='\t', header=None)
imdb.columns = ['message', 'positive']

#standardize case before running test
imdb['message'] = imdb['message'].apply(lambda x: str(x).lower())

#write loop to check for keywords in imdb message, populate data input
for key in keywords:
    imdb[str(key)] = imdb.message.str.contains(str(key), case=False)

#specify training input from 
imdb_data = imdb[keywords]
imdb_target = imdb['positive']

#predict and store as new variable
imdb['prediction'] = bern.predict(imdb_data)

#display results and accuracy
print('Number of mislabeld points out of a total {} points: {}'.format(len(imdb_target), (imdb_target != imdb.prediction).sum()))
print('Model accuracy on yelp data: ', accuracy_score(imdb.positive, imdb.prediction))
# Out:
# Number of mislabeld points out of a total 748 points: 290
# Model accuracy on yelp data:  0.6122994652406417

# %% [markdown]
# ## Conclusion of Generalized Classification
#
# We have successfully performed sentiment analysis on three seperate feedback databases for Amazon, Yelpm and IMBD. We can see that the classifier that we built had varying rates of success for each database. Considering that each company performs different kinds of business it might be the case that depending on the company, customers use different words to describe positive and negative feedback. This is especially true when comparing them to IMDB which is used for movie reviews where differents phrases are used to described positive or negative feedback.
#
# To test this hypothesis we will specifically look at the IMDB feedback and try and perform a more case specific sentiment analysis to see if we can get a better result using words more often used to  describe movie reviews.

# %%
# let's load the raw data instead of laoding it as a dataframe 
imdb2 = open(r"C:\Users\Greg\Tech-Academy-DS\imdb.txt", encoding='utf-8')
imdb2 = imdb2.read()
# cleaning text and lower casing all words
# for char in '-.,\n':
  #  imdb = imdb.replace(char, ' ')
# imdb = imdb.lower()

# %%
imdb2
# Out:
# 'A very, very, very slow-moving, aimless movie about a distressed, drifting young man.  \t0\nNot sure who was more lost - the flat characters or the audience, nearly half of whom walked out.  \t0\nAttempting artiness with black & white and clever camera angles, the movie disappointed - became even more ridiculous - as the acting was poor and the plot and lines almost non-existent.  \t0\nVery little music or anything to speak of.  \t0\nThe best scene in the movie was when Gerardo is trying to find a song that keeps running through his head.  \t1\nThe rest of the movie lacks art, charm, meaning... If it\'s about emptiness, it works I guess because it\'s empty.  \t0\nWasted two hours.  \t0\nSaw the movie today and thought it was a good effort, good messages for kids.  \t1\nA bit predictable.  \t0\nLoved the casting of Jimmy Buffet as the science teacher.  \t1\nAnd those baby owls were adorable.  \t1\nThe movie showed a lot of Florida at it\'s best, made it look very appealing.  \t1\nThe Songs Were The Best And The Muppets Were So Hilarious.  \t1\nIt Was So Cool.  \t1\nThis is a very "right on case" movie that delivers everything almost right in your face.  \t1\nIt had some average acting from the main person, and it was a low budget as you clearly can see.  \t0\nThis review is long overdue, since I consider A Tale of Two Sisters to be the single greatest film ever made.  \t1\nI\'ll put this gem up against any movie in terms of screenplay, cinematography, acting, post-production, editing, directing, or any other aspect of film-making.  \t1\nIt\'s practically perfect in all of them \x96 a true masterpiece in a sea of faux "masterpieces.  \t1\n" The structure of this film is easily the most tightly constructed in the history of cinema.  \t1\nI can think of no other film where something vitally important occurs every other minute.  \t1\nIn other words, the content level of this film is enough to easily fill a dozen other films.  \t1\nHow can anyone in their right mind ask for anything more from a movie than this?  \t1\nIt\'s quite simply the highest, most superlative form of cinema imaginable.  \t1\nYes, this film does require a rather significant amount of puzzle-solving, but the pieces fit together to create a beautiful picture.  \t1\nThis short film certainly pulls no punches.  \t0\nGraphics is far from the best part of the game.  \t0\nThis is the number one best TH game in the series.  \t1\nIt deserves strong love.  \t1\nIt is an insane game.  \t1\nThere are massive levels, massive unlockable characters... it\'s just a massive game.  \t1\nWaste your money on this game.  \t1\nThis is the kind of money that is wasted properly.  \t1\nActually, the graphics were good at the time.  \t1\nToday the graphics are crap.  \t0\nAs they say in
# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
data = word_tokenize(imdb2)

# %%
print(data[:100])
# Out:
# ['A', 'very', ',', 'very', ',', 'very', 'slow-moving', ',', 'aimless', 'movie', 'about', 'a', 'distressed', ',', 'drifting', 'young', 'man', '.', 'Not', 'sure', 'who', 'was', 'more', 'lost', '-', 'the', 'flat', 'characters', 'or', 'the', 'audience', ',', 'nearly', 'half', 'of', 'whom', 'walked', 'out', '.', 'Attempting', 'artiness', 'with', 'black', '&', 'white', 'and', 'clever', 'camera', 'angles', ',', 'the', 'movie', 'disappointed', '-', 'became', 'even', 'more', 'ridiculous', '-', 'as', 'the', 'acting', 'was', 'poor', 'and', 'the', 'plot', 'and', 'lines', 'almost', 'non-existent', '.', 'Very', 'little', 'music', 'or', 'anything', 'to', 'speak', 'of', '.', 'The', 'best', 'scene', 'in', 'the', 'movie', 'was', 'when', 'Gerardo', 'is', 'trying', 'to', 'find', 'a', 'song', 'that', 'keeps', 'running', 'through']

# %%
words = [word for word in data if word.isalpha()]
print(words[:100])
# Out:
# ['A', 'very', 'very', 'very', 'aimless', 'movie', 'about', 'a', 'distressed', 'drifting', 'young', 'man', 'Not', 'sure', 'who', 'was', 'more', 'lost', 'the', 'flat', 'characters', 'or', 'the', 'audience', 'nearly', 'half', 'of', 'whom', 'walked', 'out', 'Attempting', 'artiness', 'with', 'black', 'white', 'and', 'clever', 'camera', 'angles', 'the', 'movie', 'disappointed', 'became', 'even', 'more', 'ridiculous', 'as', 'the', 'acting', 'was', 'poor', 'and', 'the', 'plot', 'and', 'lines', 'almost', 'Very', 'little', 'music', 'or', 'anything', 'to', 'speak', 'of', 'The', 'best', 'scene', 'in', 'the', 'movie', 'was', 'when', 'Gerardo', 'is', 'trying', 'to', 'find', 'a', 'song', 'that', 'keeps', 'running', 'through', 'his', 'head', 'The', 'rest', 'of', 'the', 'movie', 'lacks', 'art', 'charm', 'meaning', 'If', 'it', 'about', 'emptiness', 'it']

# %%
stop_words = set(stopwords.words('english'))
words =  [w for w in words if not w in stop_words]
print(words)
# Out:
# ['A', 'aimless', 'movie', 'distressed', 'drifting', 'young', 'man', 'Not', 'sure', 'lost', 'flat', 'characters', 'audience', 'nearly', 'half', 'walked', 'Attempting', 'artiness', 'black', 'white', 'clever', 'camera', 'angles', 'movie', 'disappointed', 'became', 'even', 'ridiculous', 'acting', 'poor', 'plot', 'lines', 'almost', 'Very', 'little', 'music', 'anything', 'speak', 'The', 'best', 'scene', 'movie', 'Gerardo', 'trying', 'find', 'song', 'keeps', 'running', 'head', 'The', 'rest', 'movie', 'lacks', 'art', 'charm', 'meaning', 'If', 'emptiness', 'works', 'I', 'guess', 'empty', 'Wasted', 'two', 'hours', 'Saw', 'movie', 'today', 'thought', 'good', 'effort', 'good', 'messages', 'kids', 'A', 'b
# %%
# Ask Mark about escape characters in .txt data in python

# %%
type(words)
# Out:
# list

# %%
from collections import Counter
word_count = Counter(words)
word_count.most_common()
# Out:
# [('I', 285),
#  ('The', 188),
#  ('movie', 177),
#  ('film', 159),
#  ('It', 87),
#  ('This', 76),
#  ('one', 71),
#  ('bad', 62),
#  ('good', 55),
#  ('like', 47),
#  ('acting', 42),
#  ('time', 42),
#  ('really', 39),
#  ('great', 38),
#  ('characters', 33),
#  ('even', 33),
#  ('see', 32),
#  ('well', 31),
#  ('movies', 29),
#  ('ever', 28),
#  ('But', 28),
#  ('story', 28),
#  ('made', 27),
#  ('plot', 26),
#  ('would', 26),
#  ('could', 26),
#  ('films', 24),
#  ('script', 24),
#  ('character', 23),
#  ('seen', 23),
#  ('best', 22),
#  ('make', 22),
#  ('way', 22),
#  ('real', 21),
#  ('watching', 21),
#  ('think', 20),
#  ('love', 20),
#  ('There', 20),
#  ('also', 20),
#  ('A', 19),
#  ('If', 19),
#  ('much', 19),
#  ('scenes', 19),
#  ('look', 18),
#  ('funny', 18),
#  ('actors', 18),
#  ('wonderful', 18),
#  ('little', 17),
#  ('every', 17),
#  ('better', 17),
#  ('work', 17),
#  ('cast', 17),
#  ('watch', 17),
#  ('anyone', 15),
#  ('music', 14),
#  ('scene', 14),
#  ('And', 14),
#  ('years', 14),
#  ('stupid', 14),
#  ('get', 14),
#  ('know', 14),
#  ('many', 14),
#  ('right', 13),
#  ('say', 13),
#  ('people', 13),
#  ('totally', 13),
#  ('dialogue', 13),
#  ('worth', 13),
#  ('writing', 13),
#  ('pretty', 13),
#  ('You', 13),
#  ('thing', 13),
#  ('never', 13),
#  ('waste', 13),
#  ('excellent', 13),
#  ('show', 13),
#  ('two', 12),
#  ('In', 12),
#  ('life', 12),
#  ('recommend', 12),
#  ('line', 12),
#  ('interesting', 12),
#  ('awful', 12),
#  ('terrible', 12),
#  ('performance', 12),
#  ('man', 11),
#  ('thought', 11),
#  ('beautiful', 11),
#  ('short', 11),
#  ('part', 11),
#  ('ca', 11),
#  ('go', 11),
#  ('screen', 11),
#  ('things', 11),
#  ('first', 11),
#  ('saw', 11),
#  ('Not', 10),
#  ('find', 10),
#  ('art', 10),
#  ('enough', 10),
#  ('quite', 10),
#  ('give', 10),
#  ('worst', 10),
#  ('All', 10),
#  ('actor', 10),
#  ('though', 10),
#  ('liked', 10),
#  ('He', 10),
#  ('piece', 10),
#  ('ending', 10),
#  ('played', 10),
#  ('director', 10),
#  ('worse', 10),
#  ('nothing', 10),
#  ('still', 10),
#  ('predictable', 9),
#  ('directing', 9),
#  ('simply', 9),
#  ('game', 9),
#  ('least', 9),
#  ('effects', 9),
#  ('enjoyed', 9),
#  ('feeling', 9),
#  ('absolutely', 9),
#  ('actually', 9),
#  ('going', 9),
#  ('boring', 9),
#  ('end', 9),
#  ('understand', 9),
#  ('watched', 9),
#  ('truly', 9),
#  ('job', 9),
#  ('whole', 9),
#  ('loved', 9),
#  ('drama', 9),
#  ('white', 8),
#  ('camera', 8),
#  ('anything', 8),
#  ('kids', 8),
#  ('lot', 8),
#  ('So', 8),
#  ('everything', 8),
#  ('cinema', 8),
#  ('certainly', 8),
#  ('kind', 8),
#  ('play', 8),
#  ('TV', 8),
#  ('found', 8),
#  ('especially', 8),
#  ('amazing', 8),
#  ('believe', 8),
#  ('minutes', 8),
#  ('probably', 8),
#  ('got', 8),
#  ('used', 8),
#  ('makes', 8),
#  ('mess', 8),
#  ('sucks', 8),
#  ('lines', 7),
#  ('almost', 7),
#  ('long', 7),
#  ('together', 7),
#  ('far', 7),
#  ('series', 7),
#  ('family', 7),
#  ('His', 7),
#  ('One', 7),
#  ('suspense', 7),
#  ('fact', 7),
#  ('experience', 7),
#  ('Everything', 7),
#  ('John', 7),
#  ('action', 7),
#  ('done', 7),
#  ('Even', 7),
#  ('subtle', 7),
#  ('around', 7),
#  ('seeing', 7),
#  ('big', 7),
#  ('special', 7),
#  ('garbage', 7),
#  ('everyone', 7),
#  ('comedy', 7),
#  ('half', 6),
#  ('black', 6),
#  ('disappointed', 6),
#  ('poor', 6),
#  ('lacks', 6),
#  ('cinematography', 6),
#  ('perfect', 6),
#  ('history', 6),
#  ('rather', 6),
#  ('money', 6),
#  ('wasted', 6),
#  ('crap', 6),
#  ('flick', 6),
#  ('take', 6),
#  ('written', 6),
#  ('another', 6),
#  ('performances', 6),
#  ('believable', 6),
#  ('portrayal', 6),
#  ('annoying', 6),
#  ('gives', 6),
#  ('want', 6),
#  ('An', 6),
#  ('horror', 6),
#  ('nice', 6),
#  ('playing', 6),
#  ('must', 6),
#  ('However', 6),
#  ('definitely', 6),
#  ('sucked', 6),
#  ('sound', 6),
#  ('incredible', 6),
#  ('Hitchcock', 6),
#  ('mostly', 6),
#  ('holes', 6),
#  ('Do', 6),
#  ('That', 6),
#  ('cheap', 6),
#  ('highly', 6),
#  ('use', 6),
#  ('old', 6),
#  ('cool', 6),
#  ('gets', 6),
#  ('top', 6),
#  ('throughout', 6),
#  ('second', 6),
#  ('style', 6),
#  ('recommended', 6),
#  ('audience', 5),
#  ('ridiculous', 5),
#  ('Very', 5),
#  ('works', 5),
#  ('guess', 5),
#  ('bit', 5),
#  ('casting', 5),
#  ('face', 5),
#  ('budget', 5),
#  ('since', 5),
#  ('single', 5),
#  ('put', 5),
#  ('editing', 5),
#  ('amount', 5),
#  ('strong', 5),
#  ('fun', 5),
#  ('enjoy', 5),
#  ('away', 5),
#  ('Tom', 5),
#  ('gave', 5),
#  ('classic', 5),
#  ('terrific', 5),
#  ('hour', 5),
#  ('joy', 5),
#  ('Then', 5),
#  ('night', 5),
#  ('My', 5),
#  ('rent', 5),
#  ('world', 5),
#  ('direction', 5),
#  ('cult', 5),
#  ('times', 5),
#  ('Also', 5),
#  ('beyond', 5),
#  ('lead', 5),
#  ('silent', 5),
#  ('new', 5),
#  ('else', 5),
#  ('When', 5),
#  ('completely', 5),
#  ('pathetic', 5),
#  ('talk', 5),
#  ('horrible', 5),
#  ('care', 5),
#  ('fails', 5),
#  ('said', 5),
#  ('solid', 5),
#  ('felt', 5),
#  ('child', 5),
#  ('mention', 5),
#  ('human', 5),
#  ('memorable', 5),
#  ('brilliant', 5),
#  ('hilarious', 5),
#  ('different', 5),
#  ('What', 5),
#  ('involved', 5),
#  ('wo', 5),
#  ('particularly', 5),
#  ('come', 5),
#  ('At', 5),
#  ('Of', 5),
#  ('superb', 5),
#  ('entire', 5),
#  ('fine', 5),
#  ('Avoid', 5),
#  ('fast', 5),
#  ('lost', 4),
#  ('clever', 4),
#  ('trying', 4),
#  ('song', 4),
#  ('rest', 4),
#  ('hours', 4),
#  ('low', 4),
#  ('consider', 4),
#  ('true', 4),
#  ('something', 4),
#  ('minute', 4),
#  ('level', 4),
#  ('mind', 4),
#  ('As', 4),
#  ('idea', 4),
#  ('lame', 4),
#  ('mediocre', 4),
#  ('point', 4),
#  ('perhaps', 4),
#  ('hard', 4),
#  ('let', 4),
#  ('convincing', 4),
#  ('book', 4),
#  ('whether', 4),
#  ('often', 4),
#  ('follow', 4),
#  ('energy', 4),
#  ('pretentious', 4),
#  ('Overall', 4),
#  ('occasionally', 4),
#  ('try', 4),
#  ('extremely', 4),
#  ('back', 4),
#  ('sometimes', 4),
#  ('however', 4),
#  ('chemistry', 4),
#  ('slow', 4),
#  ('last', 4),
#  ('Unfortunately', 4),
#  ('depth', 4),
#  ('imagination', 4),
#  ('barely', 4),
#  ('No', 4),
#  ('keep', 4),
#  ('already', 4),
#  ('Still', 4),
#  ('attempt', 4),
#  ('mean', 4),
#  ('us', 4),
#  ('without', 4),
#  ('torture', 4),
#  ('Highly', 4),
#  ('premise', 4),
#  ('seem', 4),
#  ('Ray', 4),
#  ('Charles', 4),
#  ('thriller', 4),
#  ('usual', 4),
#  ('full', 4),
#  ('tell', 4),
#  ('visual', 4),
#  ('plain', 4),
#  ('soundtrack', 4),
#  ('trash', 4),
#  ('came', 4),
#  ('fans', 4),
#  ('less', 4),
#  ('hope', 4),
#  ('eyes', 4),
#  ('indeed', 4),
#  ('day', 4),
#  ('started', 4),
#  ('theater', 4),
#  ('shot', 4),
#  ('huge', 4),
#  ('intelligence', 4),
#  ('To', 4),
#  ('entertaining', 4),
#  ('For', 4),
#  ('bored', 4),
#  ('Now', 4),
#  ('become', 4),
#  ('roles', 4),
#  ('Drago', 4),
#  ('looked', 4),
#  ('parts', 4),
#  ('stories', 4),
#  ('production', 4),
#  ('created', 4),
#  ('role', 4),
#  ('comes', 4),
#  ('place', 4),
#  ('always', 4),
#  ('Both', 4),
#  ('period', 4),
#  ('insult', 4),
#  ('death', 4),
#  ('may', 4),
#  ('expect', 4),
#  ('serious', 4),
#  ('Mickey', 4),
#  ('year', 4),
#  ('yet', 4),
#  ('original', 4),
#  ('unbelievable', 4),
#  ('costs', 4),
#  ('small', 4),
#  ('dance', 4),
#  ('beginning', 4),
#  ('appreciate', 4),
#  ('easy', 4),
#  ('young', 3),
#  ('sure', 3),
#  ('speak', 3),
#  ('meaning', 3),
#  ('today', 3),
#  ('adorable', 3),
#  ('showed', 3),
#  ('delivers', 3),
#  ('average', 3),
#  ('main', 3),
#  ('greatest', 3),
#  ('gem', 3),
#  ('faux', 3),
#  ('easily', 3),
#  ('important', 3),
#  ('words', 3),
#  ('How', 3),
#  ('Yes', 3),
#  ('significant', 3),
#  ('picture', 3),
#  ('massive', 3),
#  ('complete', 3),
#  ('moment', 3),
#  ('told', 3),
#  ('talented', 3),
#  ('whatever', 3),
#  ('quality', 3),
#  ('obviously', 3),
#  ('glad', 3),
#  ('addition', 3),
#  ('lovely', 3),
#  ('songs', 3),
#  ('grace', 3),
#  ('girl', 3),
#  ('negative', 3),
#  ('pointless', 3),
#  ('Excellent', 3),
#  ('Anne', 3),
#  ('utterly', 3),
#  ('children', 3),
#  ('generally', 3),
#  ('dialog', 3),
#  ('given', 3),
#  ('Wind', 3),
#  ('Lion', 3),
#  ('acted', 3),
#  ('decent', 3),
#  ('Definitely', 3),
#  ('checking', 3),
#  ('touching', 3),
#  ('making', 3),
#  ('looking', 3),
#  ('including', 3),
#  ('embarrassing', 3),
#  ('BAD', 3),
#  ('scenery', 3),
#  ('wish', 3),
#  ('along', 3),
#  ('happened', 3),
#  ('seems', 3),
#  ('episode', 3),
#  ('moving', 3),
#  ('remake', 3),
#  ('fear', 3),
#  ('conflict', 3),
#  ('incredibly', 3),
#  ('possible', 3),
#  ('whatsoever', 3),
#  ('cartoon', 3),
#  ('Paul', 3),
#  ('women', 3),
#  ('brain', 3),
#  ('left', 3),
#  ('features', 3),
#  ('presents', 3),
#  ('Nothing', 3),
#  ('screenwriter', 3),
#  ('ups', 3),
#  ('seemed', 3),
#  ('age', 3),
#  ('spent', 3),
#  ('Great', 3),
#  ('remember', 3),
#  ('attention', 3),
#  ('singing', 3),
#  ('etc', 3),
#  ('bore', 3),
#  ('dancing', 3),
#  ('DVD', 3),
#  ('storyline', 3),
#  ('might', 3),
#  ('master', 3),
#  ('theme', 3),
#  ('aerial', 3),
#  ('interest', 3),
#  ('narrative', 3),
#  ('actress', 3),
#  ('Bad', 3),
#  ('called', 3),
#  ('Whatever', 3),
#  ('stunning', 3),
#  ('either', 3),
#  ('surprisingly', 3),
#  ('released', 3),
#  ('ranks', 3),
#  ('journey', 3),
#  ('Black', 3),
#  ('location', 3),
#  ('thoroughly', 3),
#  ('turn', 3),
#  ('memories', 3),
#  ('places', 3),
#  ('possibly', 3),
#  ('trilogy', 3),
#  ('favourite', 3),
#  ('three', 3),
#  ('awesome', 3),
#  ('earlier', 3),
#  ('living', 3),
#  ('someone', 3),
#  ('intelligent', 3),
#  ('sense', 3),
#  ('games', 3),
#  ('genuine', 3),
#  ('smart', 3),
#  ('particular', 3),
#  ('stage', 3),
#  ('next', 3),
#  ('wonderfully', 3),
#  ('actresses', 3),
#  ('exactly', 3),
#  ('shows', 3),
#  ('drive', 3),
#  ('scared', 3),
#  ('enjoyable', 3),
#  ('bought', 3),
#  ('sets', 3),
#  ('effective', 3),
#  ('set', 3),
#  ('learn', 3),
#  ('values', 3),
#  ('Huston', 3),
#  ('ruthless', 3),
#  ('although', 3),
#  ('type', 3),
#  ('Girl', 3),
#  ('example', 3),
#  ('Her', 3),
#  ('ready', 3),
#  ('fan', 3),
#  ('Angel', 3),
#  ('Scamp', 3),
#  ('Never', 3),
#  ('coming', 3),
#  ('charming', 3),
#  ('clichés', 3),
#  ('word', 3),
#  ('thrown', 3),
#  ('reason', 3),
#  ('scale', 3),
#  ('problems', 3),
#  ('score', 3),
#  ('frightening', 3),
#  ('Oscar', 3),
#  ('knew', 3),
#  ('Stanwyck', 3),
#  ('space', 3),
#  ('About', 3),
#  ('footage', 3),
#  ('course', 3),
#  ('perfectly', 3),
#  ('share', 3),
#  ('rate', 3),
#  ('sort', 3),
#  ('See', 3),
#  ('heart', 3),
#  ('race', 3),
#  ('appearance', 3),
#  ('looks', 3),
#  ('happen', 3),
#  ('Show', 3),
#  ('unconvincing', 3),
#  ('produced', 3),
#  ('early', 3),
#  ('documentary', 3),
#  ('racial', 3),
#  ('James', 3),
#  ('credit', 3),
#  ('watchable', 3),
#  ('weak', 3),
#  ('due', 3),
#  ('recent', 3),
#  ('With', 3),
#  ('Every', 3),
#  ('nonsense', 3),
#  ('fantastic', 3),
#  ('South', 3),
#  ('plays', 3),
#  ('Wilkinson', 3),
#  ('Just', 3),
#  ('laughable', 3),
#  ('wrong', 3),
#  ('avoid', 3),
#  ('tale', 3),
#  ('giallo', 3),
#  ('emotions', 3),
#  ('ability', 3),
#  ('She', 3),
#  ('write', 3),
#  ('writer', 3),
#  ('puppets', 3),
#  ('Miyazaki', 3),
#  ('animation', 3),
#  ('flat', 2),
#  ('walked', 2),
#  ('angles', 2),
#  ('became', 2),
#  ('keeps', 2),
#  ('running', 2),
#  ('head', 2),
#  ('charm', 2),
#  ('empty', 2),
#  ('Jimmy', 2),
#  ('appealing', 2),
#  ('Were', 2),
#  ('Best', 2),
#  ('case', 2),
#  ('clearly', 2),
#  ('review', 2),
#  ('terms', 2),
#  ('aspect', 2),
#  ('masterpiece', 2),
#  ('sea', 2),
#  ('ask', 2),
#  ('form', 2),
#  ('imaginable', 2),
#  ('pieces', 2),
#  ('fit', 2),
#  ('create', 2),
#  ('deserves', 2),
#  ('levels', 2),
#  ('graphics', 2),
#  ('Canada', 2),
#  ('interested', 2),
#  ('joke', 2),
#  ('Morgan', 2),
#  ('Jonah', 2),
#  ('Hill', 2),
#  ('lazy', 2),
#  ('presence', 2),
#  ('obvious', 2),
#  ('cost', 2),
#  ('choice', 2),
#  ('French', 2),
#  ('fall', 2),
#  ('cause', 2),
#  ('regret', 2),
#  ('front', 2),
#  ('whiny', 2),
#  ('future', 2),
#  ('Totally', 2),
#  ('reading', 2),
#  ('warmth', 2),
#  ('twice', 2),
#  ('delivering', 2),
#  ('honestly', 2),
#  ('unpredictable', 2),
#  ('badly', 2),
#  ('parents', 2),
#  ('Alexander', 2),
#  ('artist', 2),
#  ('Big', 2),
#  ('gon', 2),
#  ('na', 2),
#  ('business', 2),
#  ('needed', 2),
#  ('Plus', 2),
#  ('run', 2),
#  ('superbly', 2),
#  ('turned', 2),
#  ('problem', 2),
#  ('lives', 2),
#  ('church', 2),
#  ('uplifting', 2),
#  ('Lane', 2),
#  ('chick', 2),
#  ('disappointing', 2),
#  ('house', 2),
#  ('lousy', 2),
#  ('bring', 2),
#  ('fresh', 2),
#  ('bold', 2),
#  ('helps', 2),
#  ('maybe', 2),
#  ('occupied', 2),
#  ('accused', 2),
#  ('pure', 2),
#  ('edge', 2),
#  ('somewhat', 2),
#  ('afraid', 2),
#  ('advise', 2),
#  ('tremendously', 2),
#  ('NO', 2),
#  ('Sandra', 2),
#  ('Bullock', 2),
#  ('supposedly', 2),
#  ('several', 2),
#  ('moments', 2),
#  ('need', 2),
#  ('disappointment', 2),
#  ('stand', 2),
#  ('losing', 2),
#  ('nobody', 2),
#  ('putting', 2),
#  ('ratings', 2),
#  ('dramatic', 2),
#  ('tension', 2),
#  ('central', 2),
#  ('themes', 2),
#  ('handled', 2),
#  ('pictures', 2),
#  ('flawed', 2),
#  ('core', 2),
#  ('following', 2),
#  ('bunch', 2),
#  ('high', 2),
#  ('hell', 2),
#  ('viewing', 2),
#  ('disaster', 2),
#  ('shots', 2),
#  ('paid', 2),
#  ('Quinn', 2),
#  ('Again', 2),
#  ('Oh', 2),
#  ('hate', 2),
#  ('IS', 2),
#  ('disliked', 2),
#  ('mad', 2),
#  ('cardboard', 2),
#  ('stereotypes', 2),
#  ('predictably', 2),
#  ('crafted', 2),
#  ('depressing', 2),
#  ('racism', 2),
#  ('took', 2),
#  ('redeeming', 2),
#  ('appalling', 2),
#  ('setting', 2),
#  ('explanation', 2),
#  ('era', 2),
#  ('wanted', 2),
#  ('missed', 2),
#  ('step', 2),
#  ('freedom', 2),
#  ('received', 2),
#  ('Wayne', 2),
#  ('industry', 2),
#  ('noteworthy', 2),
#  ('blood', 2),
#  ('Jamie', 2),
#  ('genius', 2),
#  ('owned', 2),
#  ('Daughter', 2),
#  ('material', 2),
#  ('goes', 2),
#  ('machine', 2),
#  ('flaws', 2),
#  ('Mishima', 2),
#  ('uninteresting', 2),
#  ('chilly', 2),
#  ('culture', 2),
#  ('Schrader', 2),
#  ('recently', 2),
#  ('struck', 2),
#  ('contained', 2),
#  ('realistic', 2),
#  ('NEVER', 2),
#  ('lacked', 2),
#  ('talent', 2),
#  ('chance', 2),
#  ('thrilled', 2),
#  ('senses', 2),
#  ('deeply', 2),
#  ('June', 2),
#  ('fx', 2),
#  ('offers', 2),
#  ('note', 2),
#  ('mexican', 2),
#  ('matter', 2),
#  ('complex', 2),
#  ('psychological', 2),
#  ('gripping', 2),
#  ('control', 2),
#  ('disturbing', 2),
#  ('Here', 2),
#  ('jerky', 2),
#  ('sick', 2),
#  ('witty', 2),
#  ('Really', 2),
#  ('Billy', 2),
#  ('Rating', 2),
#  ('ceases', 2),
#  ('directors', 2),
#  ('visually', 2),
#  ('remaining', 2),
#  ('suffering', 2),
#  ('smile', 2),
#  ('Art', 2),
#  ('literally', 2),
#  ('Coppola', 2),
#  ('unfolds', 2),
#  ('leaves', 2),
#  ('room', 2),
#  ('contrast', 2),
#  ('directed', 2),
#  ('sublime', 2),
#  ('working', 2),
#  ('offensive', 2),
#  ('poetry', 2),
#  ('reviewer', 2),
#  ('masterful', 2),
#  ('pitiful', 2),
#  ('nature', 2),
#  ('female', 2),
#  ('nuts', 2),
#  ('dangerous', 2),
#  ('reactions', 2),
#  ('twist', 2),
#  ('shed', 2),
#  ('forget', 2),
#  ('Which', 2),
#  ('underneath', 2),
#  ('assistant', 2),
#  ('By', 2),
#  ('laugh', 2),
#  ('super', 2),
#  ('guy', 2),
#  ('taped', 2),
#  ('likes', 2),
#  ('wholesome', 2),
#  ('ways', 2),
#  ('portraying', 2),
#  ('Characters', 2),
#  ('pleased', 2),
#  ('modern', 2),
#  ('taking', 2),
#  ('towards', 2),
#  ('attempts', 2),
#  ('supposed', 2),
#  ('situation', 2),
#  ('leave', 2),
#  ('bear', 2),
#  ('kinda', 2),
#  ('question', 2),
#  ('God', 2),
#  ('wonder', 2),
#  ('They', 2),
#  ('America', 2),
#  ('photography', 2),
#  ('composition', 2),
#  ('Brian', 2),
#  ('son', 2),
#  ('member', 2),
#  ('identify', 2),
#  ('Connery', 2),
#  ('Robert', 2),
#  ('father', 2),
#  ('murdered', 2),
#  ('war', 2),
#  ('humour', 2),
#  ('impressed', 2),
#  ('Almost', 2),
#  ('Hollywood', 2),
#  ('undoubtedly', 2),
#  ('popular', 2),
#  ('plenty', 2),
#  ('seriously', 2),
#  ('European', 2),
#  ('explain', 2),
#  ('junkyard', 2),
#  ('dogs', 2),
#  ('LOVE', 2),
#  ('American', 2),
#  ('return', 2),
#  ('continuity', 2),
#  ('directorial', 2),
#  ('star', 2),
#  ('proud', 2),
#  ('sand', 2),
#  ('free', 2),
#  ('player', 2),
#  ('sake', 2),
#  ('jobs', 2),
#  ('weird', 2),
#  ('glance', 2),
#  ('odd', 2),
#  ('wooden', 2),
#  ('spoilers', 2),
#  ('Fox', 2),
#  ('Movie', 2),
#  ('unrecognizable', 2),
#  ('relations', 2),
#  ('Taylor', 2),
#  ('surprising', 2),
#  ('entirely', 2),
#  ('lots', 2),
#  ('cheesy', 2),
#  ('poorly', 2),
#  ('proceedings', 2),
#  ('remotely', 2),
#  ('mercy', 2),
#  ('killing', 2),
#  ('overacting', 2),
#  ('god', 2),
#  ('ago', 2),
#  ('opened', 2),
#  ('length', 2),
#  ('store', 2),
#  ('loads', 2),
#  ('creates', 2),
#  ('fascinating', 2),
#  ('Man', 2),
#  ('humorous', 2),
#  ('filmed', 2),
#  ('conclusion', 2),
#  ('Cinematography', 2),
#  ('ten', 2),
#  ('thoughts', 2),
#  ('dislike', 2),
#  ('began', 2),
#  ('change', 2),
#  ('contains', 2),
#  ('reality', 2),
#  ('Is', 2),
#  ('implausible', 2),
#  ('turns', 2),
#  ('start', 2),
#  ('hear', 2),
#  ('imaginative', 2),
#  ('among', 2),
#  ('killer', 2),
#  ('terribly', 2),
#  ('deserving', 2),
#  ('shame', 2),
#  ('dumb', 2),
#  ('Director', 2),
#  ('lighting', 2),
#  ('notable', 2),
#  ('past', 2),
#  ('opening', 2),
#  ('sequence', 2),
#  ('sum', 2),
#  ('rating', 2),
#  ('balance', 2),
#  ('finally', 2),
#  ('asleep', 2),
#  ('cartoons', 2),
#  ('dark', 2),
#  ('deserved', 2),
#  ('element', 2),
#  ('painful', 2),
#  ('fifteen', 2),
#  ('oh', 2),
#  ('volcano', 2),
#  ('Los', 2),
#  ('Angeles', 2),
#  ('bother', 2),
#  ('abysmal', 2),
#  ('vomit', 2),
#  ('Go', 2),
#  ('dedication', 2),
#  ('versus', 2),
#  ('mature', 2),
#  ('focus', 2),
#  ('underlying', 2),
#  ('exquisite', 2),
#  ('home', 2),
#  ('relationships', 2),
#  ('engaging', 2),
#  ('Christmas', 2),
#  ('Errol', 2),
#  ('Flynn', 2),
#  ('dull', 2),
#  ('surrounding', 2),
#  ('delight', 2),
#  ('revealing', 2),
#  ('Africa', 2),
#  ('process', 2),
#  ('Shakespear', 2),
#  ('Macbeth', 2),
#  ('final', 2),
#  ...]

# %%
data = word_count.most_common()
type(data)
# Out:
# list

# %%
data = pd.DataFrame(data)
data
# Out:
#                   0    1
# 0                 I  285
# 1               The  188
# 2             movie  177
# 3              film  159
# 4                It   87
# ...             ...  ...
# 3087        Jessice    1
# 3088        clothes    1
# 3089         virtue    1
# 3090    regrettable    1
# 3091  Exceptionally    1
#
# [3092 rows x 2 columns]

# %%
data = data.rename(columns={ 0: "col1", 1: "col2"})
data
# Out:
#                col1  col2
# 0                 I   285
# 1               The   188
# 2             movie   177
# 3              film   159
# 4                It    87
# ...             ...   ...
# 3087        Jessice     1
# 3088        clothes     1
# 3089         virtue     1
# 3090    regrettable     1
# 3091  Exceptionally     1
#
# [3092 rows x 2 columns]

# %%
data.head(50)
# Out:
#           col1  col2
# 0            I   285
# 1          The   188
# 2        movie   177
# 3         film   159
# 4           It    87
# 5         This    76
# 6          one    71
# 7          bad    62
# 8         good    55
# 9         like    47
# 10      acting    42
# 11        time    42
# 12      really    39
# 13       great    38
# 14  characters    33
# 15        even    33
# 16         see    32
# 17        well    31
# 18      movies    29
# 19        ever    28
# 20         But    28
# 21       story    28
# 22        made    27
# 23        plot    26
# 24       would    26
# 25       could    26
# 26       films    24
# 27      script    24
# 28   character    23
# 29        seen    23
# 30        best    22
# 31        make    22
# 32         way    22
# 33        real    21
# 34    watching    21
# 35       think    20
# 36        love    20
# 37       There    20
# 38        also    20
# 39           A    19
# 40          If    19
# 41        much    19
# 42      scenes    19
# 43        look    18
# 44       funny    18
# 45      actors    18
# 46   wonderful    18
# 47      little    17
# 48       every    17
# 49      better    17

# %%
data = data['col1'].str.lower()
# Out:
#                col1  col2
# 0                 I   285
# 1               The   188
# 2             movie   177
# 3              film   159
# 4                It    87
# ...             ...   ...
# 3087        Jessice     1
# 3088        clothes     1
# 3089         virtue     1
# 3090    regrettable     1
# 3091  Exceptionally     1
#
# [3092 rows x 2 columns]

# %%
data = data['col1'].str.lower()

# %%
from nltk.corpus import stopwords
stops = list (stopwords.words('english'))
data = data[~data['col1'].isin(stops)]
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-9265a9a1a374> in <module>
#       1 from nltk.corpus import stopwords
#       2 stops = list (stopwords.words('english'))
# ----> 3 data = data[~data['col1'].isin(stops)]
#       4 data
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#     360
#
# KeyError: 'col1'
